# %%
import os
import json
import gspread as gs

from time import sleep
from datetime import date
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.support.ui import WebDriverWait
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import NoSuchElementException

# # URL below look for 'tech recruiter' in 'Estonia' or' Tallin, Estonia', filtering only people and 2nd grade connections 
# # URL = "https://www.linkedin.com/search/results/people/?geoUrn=%5B%22115081480%22%2C%22102974008%22%5D&keywords=tech%20recruiter&network=%5B%22S%22%5D&origin=FACETED_SEARCH&sid=4Sb"

# # URL below look for 'recruiter portugal'
# URL = "https://www.linkedin.com/search/results/people/?keywords=recruiter%20portugal&origin=CLUSTER_EXPANSION&sid=KyI"
# c = 0
# def login_linkedin(username, password):
#     # Abre pagina do google para autenticar em SHopee Fraud Rule Engine
#     nav.get(URL)
#     # nav.maximize_window()

#     # # Clica em Entre
#     wait.until(EC.element_to_be_clickable((By.XPATH, '/html/body/div[1]/main/p[1]/a'))).click()
#     # # Envia user e pw
#     wait.until(EC.element_to_be_clickable((By.XPATH, '//*[@id="username"]'))).send_keys(username)
#     wait.until(EC.element_to_be_clickable((By.XPATH, '//*[@id="password"]'))).send_keys(password)
#     # # Clica em Entrar
#     wait.until(EC.element_to_be_clickable((By.XPATH, '//*[@id="organic-div"]/form/div[3]/button'))).click()

# def find_connect_buttons():
#     return nav.find_elements(By.XPATH, "//button/span[text()='Connect']")

# def click_send_button():
#     try:
#         send_button = wait.until(EC.element_to_be_clickable((By.XPATH, '//button/span[text()="Send"]')))
#         send_button.click()
#     except NoSuchElementException:
#         print("Botão 'Send' não encontrado. A janela não apareceu.")
#     except Exception as e:
#         print(f"Erro ao clicar no botão Send: {e}")

# def click_connect_buttons(connect_buttons):
#     global c  # Adicione esta linha para usar a variável global 'c'
#     if connect_buttons != []:
#         for button in connect_buttons:
#             if c > 60:
#                 break
#             else:
#                 try:
#                     button.click()
#                     sleep(3)  # Aguarde um pouco entre cada clique para evitar problemas de carregamento
#                     click_send_button()  # Clique no botão "Send" na janela que aparece
#                     c+=1
#                     print(c, " conexões enviadas")
#                 except Exception as e:
#                     print(f"Erro ao clicar no botão Connect ou Send: {e}")

# def go_to_next_page():
#     try:
#         sleep(5)
#         nav.find_element(By.XPATH, "//button/span[text()='Next']").click()
#         return True
#     except NoSuchElementException:
#         print("Botão 'Próxima página' não encontrado. Provavelmente estamos na última página.")
#         return False

# service = Service(ChromeDriverManager().install())
# nav = webdriver.Chrome(service=service)

# wait = WebDriverWait(nav, 10)

# login_linkedin(username, password)
# i = 1
# while True:
#     print("Page: ", i)
#     sleep(10)  # Aguarde um pouco para a página carregar completamente
#     print("Aguardei os 10s")
#     connect_buttons = find_connect_buttons()
#     click_connect_buttons(connect_buttons)
#     nav.execute_script("window.scrollTo(0, document.body.scrollHeight);")
#     has_next_page = go_to_next_page()
#     if not has_next_page:
#         break
#     i+=1

# %%
# define seu username e password do LinkedIn
username = 'jllcen2011@gmail.com'
password = '93589468jJ@'

# cria um objeto webdriver do Chrome
driver = webdriver.Chrome()

# faz o login no LinkedIn
driver.get('https://www.linkedin.com/login')
driver.find_element_by_xpath('username').send_keys(username)
driver.find_element_by_xpath('password').send_keys(password)
driver.find_element_by_xpath("//button[text()='Entrar']").click()

# cria uma variável URL com o link da página de busca já com filtros escolhidos
url = "https://www.linkedin.com/search/results/people/?keywords=recruiter%20portugal&origin=CLUSTER_EXPANSION&sid=KyI"

# navega para a página de busca
driver.get(url)

# define um contador de conexões clicadas
count = 0

# percorre a lista de resultados de busca
while count < 60:
    # verifica se o botão "connect" está presente
    try:
        connect_button = driver.find_element_by_xpath("//button[text()='Connect']")
        connect_button.click()
        count += 1
    # se o botão "connect" não estiver presente, verifica se o botão "follow" está presente
    except NoSuchElementException:
        try:
            follow_button = driver.find_element_by_xpath("//button[text()='Follow']")
            follow_button.click()
            driver.find_element_by_xpath("//a[text()='View profile']").click()
            sleep(2)
            more_button = driver.find_element_by_xpath("//button[@data-control-name='contact_see_more']")
            more_button.click()
            connect_button = driver.find_element_by_xpath("//button[text()='Connect']")
            connect_button.click()
            count += 1
            driver.back()
        # se nenhum dos botões estiver presente, passa para o próximo resultado de busca
        except NoSuchElementException:
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            sleep(2)
            next_button = driver.find_element_by_xpath("//button[@aria-label='Next']")
            next_button.click()
            sleep(2)
            
# fecha o navegador
driver.quit()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\jllce\Documents\JLLC\Estudos\Postagens Github\Linkedin\script.ipynb Cell 2 in 1
#       <a href='vscode-notebook-cell:/c%3A/Users/jllce/Documents/JLLC/Estudos/Postagens%20Github/Linkedin/script.ipynb#W1sZmlsZQ%3D%3D?line=7'>8</a> # faz o login no LinkedIn
#       <a href='vscode-notebook-cell:/c%3A/Users/jllce/Documents/JLLC/Estudos/Postagens%20Github/Linkedin/script.ipynb#W1sZmlsZQ%3D%3D?line=8'>9</a> driver.get('https://www.linkedin.com/login')
# ---> <a href='vscode-notebook-cell:/c%3A/Users/jllce/Documents/JLLC/Estudos/Postagens%20Github/Linkedin/script.ipynb#W1sZmlsZQ%3D%3D?line=9'>10</a> driver.find_element_by_xpath('username').send_keys(username)
# ...

# %%
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
from time import sleep
from selenium.webdriver.support.ui import WebDriverWait

# %%
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
from time import sleep

# define seu username e password do LinkedIn
username = 'jllcen2011@gmail.com'
password = '93589468jJ@'

# cria um objeto webdriver do Chrome
driver = webdriver.Chrome()

# faz o login no LinkedIn
driver.get('https://www.linkedin.com/login')
driver.find_element(By.XPATH, '//input[@name="session_key"]').send_keys(username)
driver.find_element(By.XPATH, '//input[@name="session_password"]').send_keys(password)
driver.find_element(By.XPATH, "//button[text()='Sign in']").click()

# cria uma variável URL com o link da página de busca já com filtros escolhidos
url = "https://www.linkedin.com/search/results/people/?keywords=recruiter%20portugal&origin=CLUSTER_EXPANSION&sid=KyI"

# Create a DataFrame to store the data
df = pd.DataFrame(columns=['Name', 'Profile_Link'])

# navega para a página de busca
driver.get(url)

# define um contador de conexões clicadas
count = 0

# percorre a lista de resultados de busca
while count < 60:
    # verifica se o botão "connect" está presente
    try:
        connect_buttons = WebDriverWait(driver, 10).until(EC.presence_of_all_elements_located((By.XPATH, "//button/span[text()='Connect']")))
        if connect_buttons:
            for button in connect_buttons:
                button.click()

        # Click the "Send now" button to send the connection request
                send_button = WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, '//button/span[text()="Send"]')))
                send_button.click() 

        # Wait for the modal to appear
                WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.XPATH, "//h3[text()='Connect']")))

                count += 1
    # se o botão "connect" não estiver presente, verifica se o botão "follow" está presente
    except NoSuchElementException:
        try:
            follow_buttons = WebDriverWait(driver, 10).until(EC.presence_of_all_elements_located((By.XPATH, "//button/span[text()='Follow']")))
            if follow_buttons:
                for button in follow_buttons:
                    button.click()
            
            
                    driver.find_element(By.XPATH, "//a[text()='View profile']").click()
                    sleep(2)
                    more_button = driver.find_element(By.XPATH, "//button/span[@data-control-name='contact_see_more']")
                    more_button.click()
                    connect_button = driver.find_element(By.XPATH, "//button/span[text()='Connect']")
                    connect_button.click()

            # Click the "Send now" button to send the connection request
                    send_now_button = WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, '//button/span[text()="Send"]')))
                    send_now_button.click() 

            # Wait for the modal to appear
                    WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.XPATH, "//h3[text()='Connect']")))

                    count += 1
                    driver.back()

        # se nenhum dos botões estiver presente, passa para o próximo resultado de busca
        except NoSuchElementException:
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            sleep(2)
            next_button = driver.find_element(By.XPATH, "//button[@aria-label='Next']")
            next_button.click()
            sleep(2)
            
# fecha o navegador
driver.quit()
# Out:
# ---------------------------------------------------------------------------
# TimeoutException                          Traceback (most recent call last)
# c:\Users\jllce\Documents\JLLC\Estudos\Postagens Github\Linkedin\script.ipynb Cell 4 in 3
#      <a href='vscode-notebook-cell:/c%3A/Users/jllce/Documents/JLLC/Estudos/Postagens%20Github/Linkedin/script.ipynb#W3sZmlsZQ%3D%3D?line=30'>31</a> while count < 60:
#      <a href='vscode-notebook-cell:/c%3A/Users/jllce/Documents/JLLC/Estudos/Postagens%20Github/Linkedin/script.ipynb#W3sZmlsZQ%3D%3D?line=31'>32</a>     # verifica se o botão "connect" está presente
#      <a href='vscode-notebook-cell:/c%3A/Users/jllce/Documents/JLLC/Estudos/Postagens%20Github/Linkedin/script.ipynb#W3sZmlsZQ%3D%3D?line=32'>33</a>     try:
# ...

# %%
a = 1
b =2
a+b
# Out:
# 3

# %%
y =a
x = b
y+x
# Out:
# 3
